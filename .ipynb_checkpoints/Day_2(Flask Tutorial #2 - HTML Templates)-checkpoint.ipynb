# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route("/<name>")
def home(name):
#     return render_template("index.html" , content = name , r =4)
      return render_template("index.html" , content = ["jatin","mahi" , "tamana"])

@app.route("/")
def def_home():
    return "<h1>Hui!<h1!>"

if __name__ == "__main__":
    app.run(debug=True, use_reloader=False , port = 8000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8000
# Press CTRL+C to quit
# 127.0.0.1 - - [14/May/2024 12:43:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2024 12:43:48] "GET /test HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 2552, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 2532, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 2529, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\AppData\Local\Temp\ipykernel_1200\3590960724.py", line 8, in home
#     return render_template("index.html" , content = ["jatin","mahi"])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\templating.py", line 147, in render_template
#     return _render(app, template, context)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\templating.py", line 130, in _render
#     rv = template.render(context)
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\environment.py", line 1301, in render
#     self.environment.handle_exception()
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\environment.py", line 936, in handle_exception
#     raise rewrite_traceback_stack(source=source)
#   File "C:\Users\Jatin\Desktop\Learning_flask_w_Python\templates\index.html", line 12, in top-level template code
#     <!--              {%if x % 2 == 0%} -->
# TypeError: not all arguments converted during string formatting
# 127.0.0.1 - - [14/May/2024 12:43:50] "GET /test HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 2552, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 2532, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 2529, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\AppData\Local\Temp\ipykernel_1200\3590960724.py", line 8, in home
#     return render_template("index.html" , content = ["jatin","mahi"])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\templating.py", line 147, in render_template
#     return _render(app, template, context)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\templating.py", line 130, in _render
#     rv = template.render(context)
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\environment.py", line 1301, in render
#     self.environment.handle_exception()
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\environment.py", line 936, in handle_exception
#     raise rewrite_traceback_stack(source=source)
#   File "C:\Users\Jatin\Desktop\Learning_flask_w_Python\templates\index.html", line 12, in top-level template code
#     <!--              {%if x % 2 == 0%} -->
# TypeError: not all arguments converted during string formatting
# 127.0.0.1 - - [14/May/2024 12:43:50] "GET /test?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2024 12:43:50] "GET /test?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2024 12:43:50] "GET /test?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2024 12:46:20] "GET /test HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2024 12:55:49] "GET /test HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 2552, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 2532, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 2529, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\AppData\Local\Temp\ipykernel_1200\3590960724.py", line 8, in home
#     return render_template("index.html" , content = ["jatin","mahi"])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\templating.py", line 146, in render_template
#     template = app.jinja_env.get_or_select_template(template_name_or_list)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\environment.py", line 1081, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\environment.py", line 1010, in get_template
#     return self._load_template(name, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\environment.py", line 969, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\loaders.py", line 137, in load
#     code = environment.compile(source, name, filename)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\environment.py", line 768, in compile
#     self.handle_exception(source=source_hint)
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\environment.py", line 936, in handle_exception
#     raise rewrite_traceback_stack(source=source)
#   File "C:\Users\Jatin\Desktop\Learning_flask_w_Python\templates\index.html", line 15, in template
#     {%elif %}
# jinja2.exceptions.TemplateSyntaxError: Expected an expression, got 'end of statement block'
# 127.0.0.1 - - [14/May/2024 12:55:49] "GET /test?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2024 12:55:49] "GET /test?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2024 12:55:50] "GET /test?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2024 12:55:50] "GET /test?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2024 12:56:07] "GET /test HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 2552, in __call__
#     return self.wsgi_app(environ, start_response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 2532, in wsgi_app
#     response = self.handle_exception(e)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 2529, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\AppData\Local\Temp\ipykernel_1200\3590960724.py", line 8, in home
#     return render_template("index.html" , content = ["jatin","mahi"])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\flask\templating.py", line 146, in render_template
#     template = app.jinja_env.get_or_select_template(template_name_or_list)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\environment.py", line 1081, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\environment.py", line 1010, in get_template
#     return self._load_template(name, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\environment.py", line 969, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\loaders.py", line 137, in load
#     code = environment.compile(source, name, filename)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\environment.py", line 768, in compile
#     self.handle_exception(source=source_hint)
#   File "C:\Users\Jatin\anaconda3\Lib\site-packages\jinja2\environment.py", line 936, in handle_exception
#     raise rewrite_traceback_stack(source=source)
#   File "C:\Users\Jatin\Desktop\Learning_flask_w_Python\templates\index.html", line 15, in template
#     {%elif %}
# jinja2.exceptions.TemplateSyntaxError: Expected an expression, got 'end of statement block'
# 127.0.0.1 - - [14/May/2024 12:56:07] "GET /test?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2024 12:56:07] "GET /test?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2024 12:56:07] "GET /test?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2024 12:56:07] "GET /test?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 304 -
# 127.0.0.1 - - [14/May/2024 12:56:37] "GET /test HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2024 12:57:06] "GET /test HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2024 12:57:07] "GET /test HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2024 12:57:07] "GET /test HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2024 12:57:08] "GET /test HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2024 12:57:08] "GET /test HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2024 12:57:08] "GET /test HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2024 12:57:08] "GET /test HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2024 12:57:08] "GET /test HTTP/1.1" 200 -

# %%
# %tb
